# %% [markdown]
# <a href="https://colab.research.google.com/github/grajkumar14-max/seaborn-data/blob/master/My%20first%20AI%20project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a scatter plot of sepal length vs sepal width, color by species
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="sepal_length", y="sepal_width", hue="species")
plt.title("Iris Dataset - Sepal Length vs Sepal Width")
plt.show()
